# %%
import pandas as pd

# %%
file_name = 'drug_experiments_df'
save_path = r'G:\My Drive\WORKING_MEMORY\PAPER\WM_manuscript_FIGURES\figures/Fig. 3. Pharma/'

all_data = pd.read_csv(save_path+file_name+'.csv', index_col=0)

# %%
all_data.drop(columns=['streak', 'total_trial'],inplace=True)

# %%
all_data.to_csv(r"C:\Users\tiffany.ona\Documents\working_memory\data" + file_name + ".csv")
